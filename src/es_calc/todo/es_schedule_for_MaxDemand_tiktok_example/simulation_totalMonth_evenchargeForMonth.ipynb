# %%
import pandas as pd
import numpy as np
from EssSimulation import EssSimulationModel
import calendar
import copy
import matplotlib.pyplot as plt

plt.rcParams['font.sans-serif']=['SimHei']    # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False    # 用来显示负号

# %%
exp_name = "estimate830"
node_name = "route_B_09"

# %%
es_info = {"transform_capacity": 63000,
           "invertband": 0,
           "soc_redundant_ratio": 0,
           "usable_depth": 0.95,
           "charge_loss": 0.92,
           "discharge_loss": 0.95,
           "es_charge_max": 8920,
           "es_charge_min": -8920,
           "es_capacity_max": 17888,
           "es_capacity_min": 0}
# es_info = {"transform_capacity": 63000,
#            "invertband": 0,
#            "soc_redundant_ratio": 0,
#            "usable_depth": 0.95,
#            "charge_loss": 0.92,
#            "discharge_loss": 0.95,
#            "es_charge_max": 9000,
#            "es_charge_min": -9000,
#            "es_capacity_max": 18000,
#            "es_capacity_min": 0}

# %%
demand_load_df = pd.read_csv(f"./data/{exp_name}/{node_name}/opt_result/demand_load.csv")
demand_load_df['time'] = pd.to_datetime(demand_load_df['time'])
demand_load_df.set_index('time', inplace=True)

strategy_df = pd.read_csv(f"./data/{exp_name}/{node_name}/opt_result/schedule_result_evencharge_old_8920_dod95.csv")
strategy_df.rename(columns={"power_opt": "value"}, inplace=True)
strategy_df['time'] = pd.to_datetime(strategy_df['time'])
strategy_df.set_index('time', inplace=True)

ele_price_df = pd.read_csv(f"./data/{exp_name}/{node_name}/opt_result/ele_price.csv")
ele_price_df['time'] = pd.to_datetime(ele_price_df['time'])
ele_price_df.set_index('time', inplace=True)

# %%
simulation_model = EssSimulationModel(es_info)
es_charge_df, es_soc_df, total_load_df = simulation_model.simulation_process(demand_load_df, strategy_df, 0) #4050
origin_balance, opt_balance = simulation_model.revenue_calculation(demand_load_df, es_charge_df, ele_price_df, 38.4)

# %%
print("测算方式一  收益：", (origin_balance - opt_balance), "收益占比：", (origin_balance - opt_balance) / origin_balance)
# Out:
# 测算方式一  收益： 349202.0344312396 收益占比： 0.06692079603862244

# %%
ori_max_demand = demand_load_df["value"].max()
opt_max_demand = total_load_df["total_load"].max()

print("调度后最大需量：", opt_max_demand, "原始最大需量：", ori_max_demand, "需量抬升成本", (opt_max_demand - ori_max_demand) * 38.4)
# Out:
# 调度后最大需量： 13434.551 原始最大需量： 10524.0 需量抬升成本 111765.15839999997

# %%
total_load_df
# Out:
#                      total_load  demand_load   es_load
# 2025-09-01 00:00:00   12974.551       9896.0 -3078.551
# 2025-09-01 00:05:00   12982.551       9904.0 -3078.551
# 2025-09-01 00:10:00   12974.551       9896.0 -3078.551
# 2025-09-01 00:15:00   12878.551       9800.0 -3078.551
# 2025-09-01 00:20:00   12958.551       9880.0 -3078.551
# ...                         ...          ...       ...
# 2025-09-30 23:35:00   10280.000      10280.0     0.000
# 2025-09-30 23:40:00   10292.000      10292.0     0.000
# 2025-09-30 23:45:00   10264.000      10264.0     0.000
# 2025-09-30 23:50:00   10252.000      10252.0     0.000
# 2025-09-30 23:55:00   10208.000      10208.0     0.000
#
# [8640 rows x 3 columns]

# %%
total_load_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 total_load_df
#
# NameError: name 'total_load_df' is not defined

# %%
4 / (2**(1/2))
# Out:
# 2.82842712474619

# %%
4/1.414
# Out:
# 2.828854314002829
